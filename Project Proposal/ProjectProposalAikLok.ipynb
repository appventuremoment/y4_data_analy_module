# %% [markdown]
# <P> <img src="https://i.ibb.co/gyNf19D/nhslogo.png" alt="nhslogo" border="0" width="100" align="right"><font size="6"><b> CS4132 Data Analytics</b> </font>

# %% [markdown]
# # Project Proposal

# %% [markdown]
# # Trends Amongst Programmers and Coding-Related Jobs by Aik Lok

# %% [markdown]
# ## Motivation and background

# %% [markdown]
# <div class="alert alert-block alert-warning">
# Give an overview of the project, motivation, background and goals.
# </div>

# %% [markdown]
# Coding has become more prominent in recent years, and now offers some of the highest paying jobs. Since this is a computer science module, every student taking this major has at least some experience in coding. Hence, I would like to seek answers to some questions pertaining to us, and could potentially change how I decide my future career path, such as what affects how much you earn working a job related to coding? Has the amount earned for coding related jobs increased over time? What proportion of people based on gender, working or otherwise, have knowledge on how to code, or in other words, is this a male-dominated field as everyone is making it out to be? What resources do people find helpful in learning how to code, and has this allowed them to further their studies in coding related majors?

# %% [markdown]
# ## Summary of Research Questions

# %% [markdown]
# <div class="alert alert-block alert-warning">
# Give a numbered list of two or more research questions. Each one should be a specific question with a specific answer, not merely a general topic or area of investigation. The question should be clear and precise. In 1-3 sentences per research question, state what are you trying to compute, and why.
# </div>

# %% [markdown]
# 1. **Were respondents able to get the jobs they wanted?** I am not quite sure what I would like to do in the future yet, but there is a non-zero probability that it will be something related to coding. I would like to know how successful other people were in achieving jobs related to coding, which in turn implies how likely it is for me to get the job (that is coding related) I (might) want. I would like to analyse the proportion of respondents that became a full time developer.
# 1. **Was most of the respondents male, implying more males do coding?** As mentioned, is coding predominantly done by males, as everyone implies, and how are they split based on different groups? The survey asked for a lot of personal information such as age, gender, race, income, education level, marital status, children status, disability, and army service status. I would like to analyse which groups are learning to code, and whether they are successful in life (based on the several different metrics provided).
# 1. **What factors affect the job and pay of each respondent? And has it increased over the years?** As mentioned, there is a chance that I get into a job with coding required. If so, what would I (theoratically) need to do in order to maximise the the pay I get from my job. I would like to analyse several different metrics which could affect the pay, as well as see the change in the average pay for each time of job related to coding over the years to evaluate whether coding as a skill has been deemed more important over the years.
# 1. **What factors affect the education level in coding related subjects?** Computer science is no easy subject. I would like to analyse what factors affect how far respondents furthered their studies in coding related subjects, to hopefully evaluate the effectiveness of different methods in learning more about computer science.
#
# ###### Final questions may be altered

# %% [markdown]
# ## Dataset

# %% [markdown]
# ### Description of data source

# %% [markdown]
# <div class="alert alert-block alert-warning">
# Numbered list of dataset (with downloadable links pointing to the exact dataset you will be using).
#
# For each link, briefly describe the dataset that will be used in the project.
#
# The data must be real — neither you nor someone else may make up the data. Do not manually perform any data cleaning steps — all data cleaning should be done programmatically, by Python code that you write. That is, you should not be searching in csv files in excel and filling in empty boxes or changing strings to numbers etc. It is possible that cleaning your data will be a big part of the code you write for your project!
# </div>

# %% [markdown]
# I will be using a singular dataset from the same source that spans 4 years (2016 to 2018, 2021). The download links are:
# 1. https://github.com/freeCodeCamp/2016-new-coder-survey/blob/master/clean-data/2016-FCC-New-Coders-Survey-Data.csv
# 2. https://github.com/freeCodeCamp/2017-new-coder-survey/blob/master/clean-data/2017-fCC-New-Coders-Survey-Data.csv
# 3. https://github.com/freeCodeCamp/2018-new-coder-survey/blob/master/clean-data/2018-fCC-New-Coders-Survey-Data.csv
# 4. https://github.com/freeCodeCamp/2021-new-coder-survey/blob/main/2021%20New%20Coder%20Survey.csv
#
# This dataset is a survey designed by CodeNewbie and Free Code Camp and was promoted by coding-related organisations to their members. At least 15,000 programmers takes this survey annually, with the exception of 2019 and 2020 likely due to the COVID-19 pandemic. The survey is conducted in 2 parts (at least in 2016-2017) and merged together at the end. This dataset was found on data.world with a link to the following GitHubs, and from there I was able to find all the years where this survey was conducted with the data publicly released.
#
# The data is in the form of each column name being either an open ended question with each cell's value being the response, or each choice in a multiple choice question which each cell's value being either 1 or 0 corresponding to true or false for. Originally, the survey was split into 2 part before the data was concatenated together, but was changed in later years.
#
# Even though the data claims to have been cleaned, skimming through the .R file they claimed to have used to clean the dataset, it appears to have standardised the format of all the cells and concatenate the 2 survey parts together. It also fills every empty cell with "NA", and no data cleaning was done. Even if it happens that the data has already been curated, I will still be performing the usual checks and data cleaning procedures.
#
# Upon further inspection, based on the ID.x and ID.y columns in the 2016 and 2017 file, we can conclude that the id of each responded has been hashed with md5 and hence I would be unable to concatenate the raw files provided myself.
#
# All relevant files will be attached along with this report.

# %% [markdown]
# ### Data Display

# %% [markdown]
# <div class="alert alert-block alert-warning">
# Summarize / Show the data files which will be used in the project.
#
# The data should be saved in `.xlsx` or `.csv` format to be submitted with the proposal. Import and display each dataset in a datafram.
#
# If you intend to scrape data, please list the websites you are scraping and a brief overview of data you wish to import. You need not finish scraping by the deadline for proposal submission, but there should be some starter code.
#
# For each dataset, give a brief overview of the data it contains, and explain the meaning of each column that is relevant to the project.
# </div>

# %% [markdown]
# `Since there are several questions and hundreds of columns, I will only be explaining any ambiguous ones. Most columns are self-explanitory, but if further clarification is required, the attached .txt document contains all of the questions in the 2016 survey and all the choices for multiple choice questions.
#
# `2016-fCC-New-Coders-Survey-Data.csv` contains but is not limited to:
#
# * CodeEventXXX: has the respondent attended the XXX in-person coding event
# * CountryCitizen: which country's citizenship does the respondent own
# * CountryLive: country where respondent lives
# * EmploymentField: industry respondent works in
# * EmploymentFieldOther: industry respondent works in, respondent chose "Other" when answering about the industry the respondent works in
# * ID.x: md5 hash of the id of respondent in first half of survey
# * ID.y: md5 hash of the id of respondent in second half of survey
# * Income: respondent's earnings in the last year
# * JobPref: respondent's preference of which type of company to work in (Startup, freelance etc.)
# * JobWherePref: location respondent would like to work (home, office etc.)
# * MoneyForLearning: money spent on learning how to code
# * MonthsProgramming: months of experience with coding
# * FinanciallySupporting: any dependents the respondent is financially supporting
# * JobInterestXXX: is respondent interested in job as an XXX (for example a front-end developer)
# * PodcastXXX: has respondent found coding-related podcast XXX helpful
# * ResourceXXX: has respondent learning resource XXX helpful`

# %%
import pandas as pd
df2016 = pd.read_csv("2016-New-Coders-Survey-Data.csv")
df2016.head()
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_8212\1866118964.py:2: DtypeWarning: Columns (21,57) have mixed types. Specify dtype option on import or set low_memory=False.
#   df2016 = pd.read_csv("2016-New-Coders-Survey-Data.csv")
#     Age  AttendedBootcamp  BootcampFinish  BootcampFullJobAfter  \
# 0  28.0               0.0             NaN                   NaN
# 1  22.0               0.0             NaN                   NaN
# 2  19.0               0.0             NaN                   NaN
# 3  26.0               0.0             NaN                   NaN
# 4  20.0               0.0             NaN                   NaN
#
#    BootcampLoanYesNo  BootcampMonthsAgo BootcampName  BootcampPostSalary  \
# 0                NaN                NaN          NaN                 NaN
# 1                NaN                NaN          NaN                 NaN
# 2                NaN                NaN          NaN                 NaN
# ...

# %% [markdown]
# `2017-fCC-New-Coders-Survey-Data.csv` contains mostly the same columns as the data in 2016, except for the addition of a new category of columns:
# * YoutubeXXX: has respondent found XXX youtube channel helpful
#
# ###### This was found by going to the freecodecamp's website and taking the survey myself to find the questions they asked.

# %%
df2017 = pd.read_csv("2017-New-Coders-Survey-Data.csv")
df2017.head()
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_16196\4028883115.py:1: DtypeWarning: Columns (17,62) have mixed types. Specify dtype option on import or set low_memory=False.
#   df2017 = pd.read_csv("2017-New-Coders-Survey-Data.csv")
#     Age  AttendedBootcamp  BootcampFinish  BootcampLoanYesNo BootcampName  \
# 0  27.0               0.0             NaN                NaN          NaN
# 1  34.0               0.0             NaN                NaN          NaN
# 2  21.0               0.0             NaN                NaN          NaN
# 3  26.0               0.0             NaN                NaN          NaN
# 4  20.0               0.0             NaN                NaN          NaN
#
#    BootcampRecommend  ChildrenNumber                 CityPopulation  \
# 0                NaN             NaN            more than 1 million
# 1                NaN             NaN              less than 100,000
# 2                NaN             NaN            more than 1 million
# ...

# %% [markdown]
# `2018-fCC-New-Coders-Survey-Data.csv` contains almost the exact same columns with the same column names as in 2017, with the addition of time taken for respondent to complete the survey in the time_total_sec column. There is also one ID used now, which could imply the survey becoming 1 part instead of being split into 2 parts. Lastly, all column names are lowercase and each word is separated by underscores instead (formatting of column names changed).

# %%
df2018 = pd.read_csv("2018-New-Coders-Survey-Data.csv")
df2018.head()
# Out:
#                                  ID  is_software_dev  is_first_dev_job  \
# 0  64e4170f7f25253d56019818b7e9fdc0              0.0               NaN
# 1  bc030166e4c7f8cb045c28ee98d5a6cd              0.0               NaN
# 2  d23d65229c00192bb5a48e73c558a0bb              0.0               NaN
# 3  c601014027aa378a84a8e4047cab50e3              0.0               NaN
# 4  3a461a8244498a13964071d93ab977ea              1.0               1.0
#
#    months_job_search                              job_pref  job_intr_fllstck  \
# 0                NaN                             freelance               NaN
# 1                NaN       work for a medium-sized company               NaN
# 2                NaN  work for a multinational corporation               1.0
# 3                NaN                             freelance               NaN
# 4                6.0                                   NaN               NaN
#
# ...

# %% [markdown]
# `2021-fCC-New-Coders-Survey-Data.csv` gives the entire question in the column name and removed the use of 1 and 0 to denote true or false for each column (denoting a choice in a multiple choice question).

# %%
df2021 = pd.read_csv("2021-New-Coders-Survey-Data.csv")
df2021.head()
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_16196\2372371879.py:1: DtypeWarning: Columns (8,9) have mixed types. Specify dtype option on import or set low_memory=False.
#   df2021 = pd.read_csv("2021-New-Coders-Survey-Data.csv")
#            Timestamp 1. What is your biggest reason for learning to code?  \
# 0  7/1/2021 10:10:23                       To succeed in current career
# 1  7/1/2021 10:31:01                                  To change careers
# 2  7/1/2021 10:42:31                                  To change careers
# 3  7/1/2021 11:06:43                                         As a hobby
# 4  7/1/2021 11:14:31                         To start your first career
#
#   2. What methods have you used to learn about coding? Please select all that apply.  \
# 0  Online resources, Books, In-person bootcamps, ...
# 1          Online resources, Books, Online bootcamps
# 2  Online resources, Books, Hackathons, Meetup.co...
# 3                            Online resources, Books
# ...

# %% [markdown]
# ## Methodology

# %% [markdown]
# <div class="alert alert-block alert-warning">
# For each research questions shortlisted, briefly explain / outline how do you plan to answer the questions.
# </div>

# %% [markdown]
# Since the questions stay relatively the same throughout the years, most of the columns are common and can be merged upon. I will do the normal data cleaning as well as group all reponse columns of the same question into one columns. I will also insert a column in each dataset stating the year the survey took place before merging.
#
# 1. **Were respondents able to get the jobs they wanted?**
#     - There is a question that asked whether each respondent became a full time developer after attending a bootcamp. There is also another question that asked if the respondent wanted a job as different types of developers. I can use that to observe the proportion of respondents that achieved a job of being a developer when they wanted a job as one before. This is under the assumption all of them got into the field and job type they wanted.
#
# 1. **Was most of the respondents male, implying more males do coding?**
#     - As mentioned, the survey asked for a lot of personal information such as age, gender, race, income, education level, marital status, children status, disability, and army service status. I could find the proportions of each group, and from there conclude the most likely traits for any given programmer, and from that conclude whether the average person who knows how to code is successful (based on the different metrics and what I define as "successful") in their life, such as pay above a certain amount.
#
# 1. **What factors affect the job and pay of each respondent? And has it increased over the years?**
#     - Based on the following factors:
#         - money spent on outside courses outside of university tuition
#         - university subject majors, degree level
#         - hours spent a week on coding
#         - months of coding experience
#         - what resources they used and found helpful (youtube channels, bootcamps etc.)
#     - find the the strength of the correlation between the factors and pay of the job. For the second part, plot the average pay of each respondent in a job related to coding against time.
#
# 1. **What factors affect the education level in coding related subjects?**
#     - Based on the following factors:
#         - gender
#         - money spent on outside courses outside of university tuition
#         - hours spent a week on coding
#         - months of coding experience
#         - what resources they used and found helpful (youtube channels, bootcamps etc.)
#     - find the the correlation between the factors and education level through proportion of each factor that has a certain degree level, since education level is categorical and not numeric (analysis done only for respondents that majored in a subject related to coding).

# %% [markdown]
# ## References

# %% [markdown]
# <div class="alert alert-block alert-warning"> Cite any references / links you may use for the project.
# </div>

# %% [markdown]
# 1. https://wordpress.com/support/markdown-quick-reference/ (markup for Jupyter when formatting proposal)
# 2. Links in `Description of data source` subsection for datasets
# 3. https://data.world/freecodecamp/new-coder-survey-2016/workspace/file?filename=survey-questions.txt (for the questions asked in the 2016 survey and what the value each number corresponds to)
# 4. https://freecodecamp.typeform.com/to/N90qR4 (most recent survey that anyone can take, used for finding the questions they asked)
# 5. https://www.freecodecamp.org/news/take-the-2017-new-coder-survey-and-help-us-build-a-massive-public-dataset-8c808cbee7eb/ (codecamp article in case the link to the currently open survey gets closed and the link is changed)
#
# There is nothing else I can think of for now so this will not be comprehensive and is subject to changes in the final project.

# %% [markdown]
# <hr>
# © NUS High School of Math & Science
